# %% [markdown]
# <a href="https://colab.research.google.com/github/AkashSeervi2003/PW_Assignment/blob/main/PythonAssignment07b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1)
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
np.random.seed(0)
x = np.random.rand(100)
y = 2 * x + np.random.normal(0, 0.1, 100)
data = pd.DataFrame({'x': x, 'y': y})
sns.scatterplot(x='x', y='y', data=data)
plt.title('Scatter Plot of Synthetic Dataset')
plt.show()

# %%
# 2)
data = np.random.randn(1000)
sns.histplot(data, kde=True)
plt.title('Distribution of Random Numbers')
plt.show()

# %%
# 3)
categories = ['A', 'B', 'C', 'D']
values = [23, 45, 56, 78]
data = pd.DataFrame({'Category': categories, 'Value': values})
sns.barplot(x='Category', y='Value', data=data)
plt.title('Comparison of Categories')
plt.show()

# %%
# 4)
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
np.random.seed(0)
categories = np.random.choice(['A', 'B', 'C'], 100)
values = np.random.randn(100)
data = pd.DataFrame({'Category': categories, 'Value': values})
sns.boxplot(x='Category', y='Value', data=data)
plt.title('Distribution of Values Across Categories')
plt.show()

# %%
# 5)
np.random.seed(0)
data = pd.DataFrame({
    'A': np.random.rand(100),
    'B': np.random.rand(100),
    'C': np.random.rand(100)
})
data['D'] = data['A'] + data['B'] + np.random.normal(0, 0.1, 100)
corr = data.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix Heatmap')
plt.show()
